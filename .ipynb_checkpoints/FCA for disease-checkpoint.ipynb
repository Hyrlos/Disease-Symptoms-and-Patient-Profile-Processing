# %% [markdown]
# # Disease_symptom_and_patient_profile_dataset for FCA

# %%
import pandas as pd

# %% [markdown]
# ## Dataset

# %%
df_complet = pd.read_csv("dataset/Disease_symptom_and_patient_profile_dataset.csv")
df_complet.sort_values(["Disease"])
# Out:
#                            Disease Fever Cough Fatigue Difficulty Breathing  \
# 112                           Acne    No    No     Yes                   No
# 97               Allergic Rhinitis    No   Yes      No                   No
# 179              Allergic Rhinitis   Yes   Yes     Yes                   No
# 205              Allergic Rhinitis   Yes    No      No                   No
# 55               Allergic Rhinitis    No    No     Yes                   No
# ..                             ...   ...   ...     ...                  ...
# 49   Urinary Tract Infection (UTI)   Yes    No      No                   No
# 310  Urinary Tract Infection (UTI)   Yes    No     Yes                   No
# 342              Williams Syndrome    No    No     Yes                   No
# 177                     Zika Virus    No   Yes     Yes                   No
# 178                     Zika Virus    No   Yes     Yes                   No
#
#      Age  Gender Blood Pressure Cholesterol Level Outcome Variable
# 112   40    Male         Normal            Normal         Negative
# 97    38  Female            Low            Normal         Negative
# 179   45    Male           High            Normal         Positive
# 205   50    Male           High              High         Negative
# 55    35  Female         Normal               Low         Negative
# ..   ...     ...            ...               ...              ...
# 49    30  Female         Normal            Normal         Positive
# 310   65    Male           High            Normal         Negative
# 342   70  Female         Normal            Normal         Positive
# 177   45  Female           High              High         Negative
# 178   45  Female           High              High         Negative
#
# [349 rows x 10 columns]

# %%
df_complet = df_complet.drop_duplicates()
df_complet = df_complet.drop("Gender", axis=1)
df_complet.sort_values(["Disease"])
# Out:
#                            Disease Fever Cough Fatigue Difficulty Breathing  \
# 112                           Acne    No    No     Yes                   No
# 55               Allergic Rhinitis    No    No     Yes                   No
# 160              Allergic Rhinitis    No   Yes     Yes                   No
# 97               Allergic Rhinitis    No   Yes      No                   No
# 205              Allergic Rhinitis   Yes    No      No                   No
# ..                             ...   ...   ...     ...                  ...
# 310  Urinary Tract Infection (UTI)   Yes    No     Yes                   No
# 74   Urinary Tract Infection (UTI)    No   Yes     Yes                   No
# 49   Urinary Tract Infection (UTI)   Yes    No      No                   No
# 342              Williams Syndrome    No    No     Yes                   No
# 177                     Zika Virus    No   Yes     Yes                   No
#
#      Age Blood Pressure Cholesterol Level Outcome Variable
# 112   40         Normal            Normal         Negative
# 55    35         Normal               Low         Negative
# 160   45           High            Normal         Negative
# 97    38            Low            Normal         Negative
# 205   50           High              High         Negative
# ..   ...            ...               ...              ...
# 310   65           High            Normal         Negative
# 74    35           High              High         Negative
# 49    30         Normal            Normal         Positive
# 342   70         Normal            Normal         Positive
# 177   45           High              High         Negative
#
# [300 rows x 9 columns]

# %% [markdown]
# ## Data processing

# %% [markdown]
# ### Age threshold

# %%
youngmedium = 25
mediumold = 65

df_complet["Young"] = "No"
df_complet["Average Age"] = "No"
df_complet["Old"] = "No"

df_complet.loc[df_complet['Age'] < youngmedium, 'Young'] = 'Yes'
df_complet.loc[(df_complet['Age'] >= youngmedium) & (df_complet['Age'] <= mediumold), 'Average Age'] = 'Yes'
df_complet.loc[df_complet['Age'] > mediumold, 'Old'] = 'Yes'
df_complet.drop("Age", axis=1, inplace = True)
df_complet
# Out:
#                Disease Fever Cough Fatigue Difficulty Breathing  \
# 0            Influenza   Yes    No     Yes                  Yes
# 1          Common Cold    No   Yes     Yes                   No
# 2               Eczema    No   Yes     Yes                   No
# 3               Asthma   Yes   Yes      No                  Yes
# 5               Eczema   Yes    No      No                   No
# ..                 ...   ...   ...     ...                  ...
# 341        Tonsillitis   Yes   Yes     Yes                   No
# 342  Williams Syndrome    No    No     Yes                   No
# 343             Stroke   Yes    No     Yes                   No
# 345             Stroke   Yes    No     Yes                   No
# 347             Stroke   Yes    No     Yes                   No
#
#     Blood Pressure Cholesterol Level Outcome Variable Young Average Age  Old
# 0              Low            Normal         Positive   Yes          No   No
# 1           Normal            Normal         Negative    No         Yes   No
# 2           Normal            Normal         Negative    No         Yes   No
# 3           Normal            Normal         Positive    No         Yes   No
# 5           Normal            Normal         Positive    No         Yes   No
# ..             ...               ...              ...   ...         ...  ...
# 341           High              High         Positive    No          No  Yes
# 342         Normal            Normal         Positive    No          No  Yes
# 343           High              High         Positive    No          No  Yes
# 345           High              High         Positive    No          No  Yes
# 347           High              High         Positive    No          No  Yes
#
# [300 rows x 11 columns]

# %% [markdown]
# ### Blood Pressure

# %%
df_complet["Low Blood Pressure"] = "No"
df_complet["High Blood Pressure"] = "No"

df_complet.loc[df_complet['Blood Pressure'] == "Low", 'Low Blood Pressure'] = 'Yes'
df_complet.loc[df_complet['Blood Pressure'] == "High", 'High Blood Pressure'] = 'Yes'

df_complet.drop("Blood Pressure", axis=1, inplace = True)
df_complet.sort_values(["Disease"])
# Out:
#                            Disease Fever Cough Fatigue Difficulty Breathing  \
# 112                           Acne    No    No     Yes                   No
# 55               Allergic Rhinitis    No    No     Yes                   No
# 160              Allergic Rhinitis    No   Yes     Yes                   No
# 97               Allergic Rhinitis    No   Yes      No                   No
# 205              Allergic Rhinitis   Yes    No      No                   No
# ..                             ...   ...   ...     ...                  ...
# 310  Urinary Tract Infection (UTI)   Yes    No     Yes                   No
# 74   Urinary Tract Infection (UTI)    No   Yes     Yes                   No
# 49   Urinary Tract Infection (UTI)   Yes    No      No                   No
# 342              Williams Syndrome    No    No     Yes                   No
# 177                     Zika Virus    No   Yes     Yes                   No
#
#     Cholesterol Level Outcome Variable Young Average Age  Old  \
# 112            Normal         Negative    No         Yes   No
# 55                Low         Negative    No         Yes   No
# 160            Normal         Negative    No         Yes   No
# 97             Normal         Negative    No         Yes   No
# 205              High         Negative    No         Yes   No
# ..                ...              ...   ...         ...  ...
# 310            Normal         Negative    No         Yes   No
# 74               High         Negative    No         Yes   No
# 49             Normal         Positive    No         Yes   No
# 342            Normal         Positive    No          No  Yes
# 177              High         Negative    No         Yes   No
#
#     Low Blood Pressure High Blood Pressure
# 112                 No                  No
# 55                  No                  No
# 160                 No                 Yes
# 97                 Yes                  No
# 205                 No                 Yes
# ..                 ...                 ...
# 310                 No                 Yes
# 74                  No                 Yes
# 49                  No                  No
# 342                 No                  No
# 177                 No                 Yes
#
# [300 rows x 12 columns]

# %% [markdown]
# ### Cholesterol Level

# %%
df_complet["Low Cholesterol Level"] = "No"
df_complet["High Cholesterol Level"] = "No"

df_complet.loc[df_complet['Cholesterol Level'] == "Low", 'Low Cholesterol Level'] = 'Yes'
df_complet.loc[df_complet['Cholesterol Level'] == "High", 'High Cholesterol Level'] = 'Yes'

df_complet.drop("Cholesterol Level", axis=1, inplace = True)
df_complet.sort_values(["Disease"])
# Out:
#                            Disease Fever Cough Fatigue Difficulty Breathing  \
# 112                           Acne    No    No     Yes                   No
# 55               Allergic Rhinitis    No    No     Yes                   No
# 160              Allergic Rhinitis    No   Yes     Yes                   No
# 97               Allergic Rhinitis    No   Yes      No                   No
# 205              Allergic Rhinitis   Yes    No      No                   No
# ..                             ...   ...   ...     ...                  ...
# 310  Urinary Tract Infection (UTI)   Yes    No     Yes                   No
# 74   Urinary Tract Infection (UTI)    No   Yes     Yes                   No
# 49   Urinary Tract Infection (UTI)   Yes    No      No                   No
# 342              Williams Syndrome    No    No     Yes                   No
# 177                     Zika Virus    No   Yes     Yes                   No
#
#     Outcome Variable Young Average Age  Old Low Blood Pressure  \
# 112         Negative    No         Yes   No                 No
# 55          Negative    No         Yes   No                 No
# 160         Negative    No         Yes   No                 No
# 97          Negative    No         Yes   No                Yes
# 205         Negative    No         Yes   No                 No
# ..               ...   ...         ...  ...                ...
# 310         Negative    No         Yes   No                 No
# 74          Negative    No         Yes   No                 No
# 49          Positive    No         Yes   No                 No
# 342         Positive    No          No  Yes                 No
# 177         Negative    No         Yes   No                 No
#
#     High Blood Pressure Low Cholesterol Level High Cholesterol Level
# 112                  No                    No                     No
# 55                   No                   Yes                     No
# 160                 Yes                    No                     No
# 97                   No                    No                     No
# 205                 Yes                    No                    Yes
# ..                  ...                   ...                    ...
# 310                 Yes                    No                     No
# 74                  Yes                    No                    Yes
# 49                   No                    No                     No
# 342                  No                    No                     No
# 177                 Yes                    No                    Yes
#
# [300 rows x 13 columns]

# %% [markdown]
# ### remove Negative Outcome Variable

# %%
df_complet.drop(df_complet[df_complet['Outcome Variable'] == "Negative"].index, inplace = True)
df_complet.drop("Outcome Variable", axis=1, inplace = True)

# %% [markdown]
# ### Remove no homogeneous disease:
# Disease present several times with différents symptom

# %%
listDuplicate = []
for name,group in df_complet.groupby(by="Disease"):
    if len(group) > 1:
        df_complet = df_complet[~df_complet['Disease'].isin([name])]

# %% [markdown]
# ### Processed Dataframe

# %%
df_complet = df_complet.set_index("Disease")

# %%
df_complet.replace({'Yes': 'x', 'No': ''}, regex=False, inplace=True)

# %%
df_complet
# Out:
#                                              Fever Cough Fatigue  \
# Disease
# Bipolar Disorder                                               x
# Cerebral Palsy                                                 x
# Colorectal Cancer                                              x
# Hypertensive Heart Disease                                     x
# Myocardial Infarction (Heart...                  x     x       x
# Urinary Tract Infection (UTI)                    x
# Common Cold                                      x             x
# Cirrhosis                                                      x
# Conjunctivitis (Pink Eye)                              x
# Malaria                                          x
# Spina Bifida                                                   x
# Chickenpox                                             x
# Eating Disorders (Anorexia,...                                 x
# Fibromyalgia                                                   x
# Hypoglycemia                                                   x
# Lymphoma                                               x
# Allergic Rhinitis                                x     x       x
# Cataracts                                                      x
# Pneumocystis Pneumonia (PCP)                     x     x       x
# Scoliosis
# Sickle Cell Anemia                                             x
# Tetanus                                                        x
# Down Syndrome                                                  x
# Ebola Virus                                      x     x       x
# Lyme Disease                                     x
# Pancreatic Cancer                                              x
# Pneumothorax                                                   x
# Hemorrhoids
# Polycystic Ovary Syndrome (PCOS)                 x     x
# Systemic Lupus Erythematosus...                        x       x
# Typhoid Fever                                          x
# Chronic Kidney Disease                                         x
# Hepatitis B                                            x       x
# Parkinson's Disease                              x     x
# Prader-Willi Syndrome                                          x
# Thyroid Cancer                                                 x
# Chronic Obstructive Pulmonary Disease (COPD)     x             x
# Dementia                                                       x
# Diverticulitis                                                 x
# Mumps                                                          x
# Gout                                             x             x
# Testicular Cancer                                              x
# Tonsillitis                                      x     x       x
# Williams Syndrome                                              x
#
#                                              Difficulty Breathing Young  \
# Disease
# Bipolar Disorder
# Cerebral Palsy                                                  x
# Colorectal Cancer
# Hypertensive Heart Disease
# Myocardial Infarction (Heart...                                 x
# Urinary Tract Infection (UTI)
# Common Cold                                                     x
# Cirrhosis
# Conjunctivitis (Pink Eye)
# Malaria
# Spina Bifida
# Chickenpox
# Eating Disorders (Anorexia,...
# Fibromyalgia
# Hypoglycemia
# Lymphoma
# Allergic Rhinitis
# Cataracts
# Pneumocystis Pneumonia (PCP)
# Scoliosis
# Sickle Cell Anemia
# Tetanus
# Down Syndrome
# Ebola Virus                                                     x
# Lyme Disease
# Pancreatic Cancer
# Pneumothorax                                                    x
# Hemorrhoids
# Polycystic Ovary Syndrome (PCOS)
# Systemic Lupus Erythematosus...
# Typhoid Fever
# Chronic Kidney Disease
# Hepatitis B
# Parkinson's Disease
# Prader-Willi Syndrome
# Thyroid Cancer
# Chronic Obstructive Pulmonary Disease (COPD)                    x
# Dementia
# Diverticulitis
# Mumps
# Gout
# Testicular Cancer
# Tonsillitis
# Williams Syndrome
#
#                                              Average Age Old  \
# Disease
# Bipolar Disorder                                       x
# Cerebral Palsy                                         x
# Colorectal Cancer                                      x
# Hypertensive Heart Disease                             x
# Myocardial Infarction (Heart...                        x
# Urinary Tract Infection (UTI)                          x
# Common Cold                                            x
# Cirrhosis                                              x
# Conjunctivitis (Pink Eye)                              x
# Malaria                                                x
# Spina Bifida                                           x
# Chickenpox                                             x
# Eating Disorders (Anorexia,...                         x
# Fibromyalgia                                           x
# Hypoglycemia                                           x
# Lymphoma                                               x
# Allergic Rhinitis                                      x
# Cataracts                                              x
# Pneumocystis Pneumonia (PCP)                           x
# Scoliosis                                              x
# Sickle Cell Anemia                                     x
# Tetanus                                                x
# Down Syndrome                                          x
# Ebola Virus                                            x
# Lyme Disease                                           x
# Pancreatic Cancer                                      x
# Pneumothorax                                           x
# Hemorrhoids                                            x
# Polycystic Ovary Syndrome (PCOS)                       x
# Systemic Lupus Erythematosus...                        x
# Typhoid Fever                                          x
# Chronic Kidney Disease                                 x
# Hepatitis B                                            x
# Parkinson's Disease                                    x
# Prader-Willi Syndrome                                  x
# Thyroid Cancer                                         x
# Chronic Obstructive Pulmonary Disease (COPD)           x
# Dementia                                               x
# Diverticulitis                                         x
# Mumps                                                  x
# Gout                                                       x
# Testicular Cancer                                          x
# Tonsillitis                                                x
# Williams Syndrome                                          x
#
#                                              Low Blood Pressure  \
# Disease
# Bipolar Disorder
# Cerebral Palsy
# Colorectal Cancer
# Hypertensive Heart Disease
# Myocardial Infarction (Heart...
# Urinary Tract Infection (UTI)
# Common Cold
# Cirrhosis
# Conjunctivitis (Pink Eye)
# Malaria
# Spina Bifida
# Chickenpox
# Eating Disorders (Anorexia,...
# Fibromyalgia
# Hypoglycemia
# Lymphoma
# Allergic Rhinitis
# Cataracts
# Pneumocystis Pneumonia (PCP)
# Scoliosis
# Sickle Cell Anemia
# Tetanus
# Down Syndrome
# Ebola Virus
# Lyme Disease
# Pancreatic Cancer
# Pneumothorax
# Hemorrhoids
# Polycystic Ovary Syndrome (PCOS)
# Systemic Lupus Erythematosus...
# Typhoid Fever
# Chronic Kidney Disease
# Hepatitis B
# Parkinson's Disease
# Prader-Willi Syndrome
# Thyroid Cancer
# Chronic Obstructive Pulmonary Disease (COPD)
# Dementia
# Diverticulitis
# Mumps
# Gout
# Testicular Cancer
# Tonsillitis
# Williams Syndrome
#
#                                              High Blood Pressure  \
# Disease
# Bipolar Disorder                                               x
# Cerebral Palsy
# Colorectal Cancer
# Hypertensive Heart Disease                                     x
# Myocardial Infarction (Heart...                                x
# Urinary Tract Infection (UTI)
# Common Cold                                                    x
# Cirrhosis
# Conjunctivitis (Pink Eye)                                      x
# Malaria                                                        x
# Spina Bifida
# Chickenpox
# Eating Disorders (Anorexia,...                                 x
# Fibromyalgia                                                   x
# Hypoglycemia                                                   x
# Lymphoma
# Allergic Rhinitis                                              x
# Cataracts
# Pneumocystis Pneumonia (PCP)                                   x
# Scoliosis                                                      x
# Sickle Cell Anemia
# Tetanus
# Down Syndrome                                                  x
# Ebola Virus
# Lyme Disease
# Pancreatic Cancer                                              x
# Pneumothorax                                                   x
# Hemorrhoids                                                    x
# Polycystic Ovary Syndrome (PCOS)
# Systemic Lupus Erythematosus...                                x
# Typhoid Fever
# Chronic Kidney Disease
# Hepatitis B
# Parkinson's Disease                                            x
# Prader-Willi Syndrome
# Thyroid Cancer                                                 x
# Chronic Obstructive Pulmonary Disease (COPD)                   x
# Dementia                                                       x
# Diverticulitis                                                 x
# Mumps
# Gout
# Testicular Cancer                                              x
# Tonsillitis                                                    x
# Williams Syndrome
#
#                                              Low Cholesterol Level  \
# Disease
# Bipolar Disorder
# Cerebral Palsy
# Colorectal Cancer
# Hypertensive Heart Disease
# Myocardial Infarction (Heart...
# Urinary Tract Infection (UTI)
# Common Cold
# Cirrhosis
# Conjunctivitis (Pink Eye)
# Malaria
# Spina Bifida
# Chickenpox
# Eating Disorders (Anorexia,...
# Fibromyalgia
# Hypoglycemia
# Lymphoma
# Allergic Rhinitis
# Cataracts
# Pneumocystis Pneumonia (PCP)
# Scoliosis
# Sickle Cell Anemia
# Tetanus
# Down Syndrome
# Ebola Virus
# Lyme Disease
# Pancreatic Cancer
# Pneumothorax
# Hemorrhoids
# Polycystic Ovary Syndrome (PCOS)
# Systemic Lupus Erythematosus...
# Typhoid Fever                                                    x
# Chronic Kidney Disease
# Hepatitis B                                                      x
# Parkinson's Disease
# Prader-Willi Syndrome
# Thyroid Cancer
# Chronic Obstructive Pulmonary Disease (COPD)
# Dementia
# Diverticulitis
# Mumps
# Gout
# Testicular Cancer
# Tonsillitis
# Williams Syndrome
#
#                                              High Cholesterol Level
# Disease
# Bipolar Disorder                                                  x
# Cerebral Palsy
# Colorectal Cancer                                                 x
# Hypertensive Heart Disease                                        x
# Myocardial Infarction (Heart...                                   x
# Urinary Tract Infection (UTI)
# Common Cold                                                       x
# Cirrhosis                                                         x
# Conjunctivitis (Pink Eye)                                         x
# Malaria                                                           x
# Spina Bifida
# Chickenpox                                                        x
# Eating Disorders (Anorexia,...                                    x
# Fibromyalgia                                                      x
# Hypoglycemia                                                      x
# Lymphoma                                                          x
# Allergic Rhinitis
# Cataracts                                                         x
# Pneumocystis Pneumonia (PCP)                                      x
# Scoliosis                                                         x
# Sickle Cell Anemia
# Tetanus                                                           x
# Down Syndrome                                                     x
# Ebola Virus
# Lyme Disease                                                      x
# Pancreatic Cancer                                                 x
# Pneumothorax                                                      x
# Hemorrhoids                                                       x
# Polycystic Ovary Syndrome (PCOS)
# Systemic Lupus Erythematosus...                                   x
# Typhoid Fever
# Chronic Kidney Disease                                            x
# Hepatitis B
# Parkinson's Disease
# Prader-Willi Syndrome
# Thyroid Cancer                                                    x
# Chronic Obstructive Pulmonary Disease (COPD)                      x
# Dementia                                                          x
# Diverticulitis                                                    x
# Mumps                                                             x
# Gout                                                              x
# Testicular Cancer                                                 x
# Tonsillitis                                                       x
# Williams Syndrome

# %%
df_complet.to_csv("FC_disease.csv")

# %% [markdown]
# ## FCA Processing

# %%
import subprocess

bashCommand = "java -jar fca4j-cli-0.4.4.jar AOCPOSET FC_disease.csv aocDisease.json -g aocDisease.dot -d FULL"
process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
output, error = process.communicate()

output
# Out:
# b'running HERMES (BITSET) data: FC_disease.csv ( 44 x 11 )\nduration: 117 ms\n'

# %%
from graphviz import Source
path = 'aocDisease.dot'
s = Source.from_file(path)

s.view()
# Out:
# 'aocDisease.dot.pdf'
